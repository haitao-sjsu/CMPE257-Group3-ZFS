# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors

df = pd.read_csv("OFFICIAL_CSV_Labeling_dataset_facebook-groups-scraper_raw_SVM_PREDICTIONS.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Column1                            1000 non-null   int64
#  1   Supply(Selling)_or_Demand(Buying)  1000 non-null   object
#  2   text                               937 non-null    object
#  3   title                              133 non-null    object
#  4   url                                1000 non-null   object
#  5   legacyId                           1000 non-null   float64
#  6   time                               1000 non-null   object
#  7   commentsCount                      1000 non-null   int64
#  8   likesCount                         1000 non-null   int64
#  9   sharesCount                        1000 non-null   int64
#  10  topComments/0/text                 457 non-null    object
#  11  topComments/1/likesCount           189 non-null    float64
#  12  topComments/1/text                 189 non-null    object
#  13  user/id                            1000 non-null   object
#  14  user/name                          1000 non-null   object
#  15  inputs                             1000 non-null   object
#  16  token                              309 non-null    object
#  17  clean_tokens                       309 non-null    object
#  18  clean_text                         309 non-null    object
#  19  rent                               702 non-null    object
#  20  location                           566 non-null    object
#  21  fromDate                           851 non-null    object
#  22  toDate                             454 non-null    object
#  23  bedrooms                           499 non-null    object
#  24  bathrooms                          416 non-null    object
#  25  amenities                          408 non-null    object
# dtypes: float64(2), int64(4), object(20)
# memory usage: 203.3+ KB

# %%
#keep only the extracted features:
df = df[['Supply(Selling)_or_Demand(Buying)','rent', 'fromDate', 'toDate', 'location', 'bedrooms', 'bathrooms']].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Supply(Selling)_or_Demand(Buying)  1000 non-null   object
#  1   rent                               702 non-null    object
#  2   fromDate                           851 non-null    object
#  3   toDate                             454 non-null    object
#  4   location                           566 non-null    object
#  5   bedrooms                           499 non-null    object
#  6   bathrooms                          416 non-null    object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %%
# Cleaning the data
# Remove spaces
# Remove symbols: $,-<
# Change Not found/anomalies into empty fields
df["rent"] = df["rent"].str.replace("$","")
df["rent"] = df["rent"].str.replace(",","")
df["rent"] = df["rent"].str.replace("-","")
df["rent"] = df["rent"].str.replace(" ","")
df["rent"] = df["rent"].str.replace("<","")
df["rent"] = df["rent"].str.replace("Notfound","")
df["rent"] = df["rent"].str.replace("NotFound","")
df["rent"] = df["rent"].str.replace("Unknown","")
df["rent"] = df["rent"].str.replace("notfound","")
df["rent"] = df["rent"].str.replace("unavailable","")
df["rent"] = df["rent"].str.replace("800to1000","800")
df["rent"] = df["rent"].str.replace("Under1000","1000")
df["rent"] = df["rent"].str.replace("8001k","800")

# Replace empty lines with nan
df = df.replace(r'^\s*$', np.nan, regex=True)
# Replace nan with 0
df["rent"] = df["rent"].fillna(0)
# Convert to float data type
df.rent = df.rent.astype(float)

# %%
# Check dataset
df.isnull().sum()
# Out:
# Supply(Selling)_or_Demand(Buying)      0
# rent                                   0
# fromDate                             149
# toDate                               546
# location                             434
# bedrooms                             501
# bathrooms                            584
# dtype: int64

# %%
# Empty location fields can be filled with San Jose, CA since the search radius was relatively small
df.location = df.location.fillna('San Jose, CA')

# %%
# Fill NaN values with 1
# A listing assumes there is at least 1 bedroom/bathroom available
df.bedrooms = df.bedrooms.fillna('1')

# %%
df.bathrooms = df.bathrooms.fillna('1')

# %%
print(df)
# Out:
#     Supply(Selling)_or_Demand(Buying)    rent    fromDate      toDate  \
# 0                              Supply     0.0  04/01/2024  05/01/2024
# 1                              Supply  1280.0  06/01/2024  08/01/2024
# 2                              Demand  1250.0  07/27/2024  08/01/2024
# 3                              Supply  1220.0  04/27/2024         NaN
# 4                              Supply  1000.0  03/01/2024  03/01/2025
# ..                                ...     ...         ...         ...
# 995                            Supply     0.0  04/27/2024  06/01/2023
# 996                            Demand     0.0  05/28/2024  08/18/2024
# 997                            Supply  1000.0  06/01/2023  12/01/2023
# 998                            Supply  1800.0  04/27/2024         NaN
# 999                           Unknown     0.0         NaN         NaN
#
#                                      location bedrooms bathrooms
# 0                                San Jose, CA        2         2
# 1               88 E San Carlos, San Jose, CA        2         3
# 2                                San Jose, CA        1         1
# 3                                San Jose, CA        1         1
# 4    Edge San Jose neighborhood, San Jose, CA        5         2
# ..                                        ...      ...       ...
# 995                              San Jose, CA        1         1
# 996                              San Jose, CA        1         1
# 997       5 minute walking distance from SJSU        2         2
# 998                              San Jose, CA        1         1
# 999                              San Jose, CA        1         1
#
# [1000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Supply(Selling)_or_Demand(Buying)  1000 non-null   object
#  1   rent                               1000 non-null   float64
#  2   fromDate                           851 non-null    object
#  3   toDate                             454 non-null    object
#  4   location                           1000 non-null   object
#  5   bedrooms                           1000 non-null   object
#  6   bathrooms                          1000 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 54.8+ KB

# %%
print(df)
# Out:
#     Supply(Selling)_or_Demand(Buying)    rent    fromDate      toDate  \
# 0                              Supply     0.0  04/01/2024  05/01/2024
# 1                              Supply  1280.0  06/01/2024  08/01/2024
# 2                              Demand  1250.0  07/27/2024  08/01/2024
# 3                              Supply  1220.0  04/27/2024         NaN
# 4                              Supply  1000.0  03/01/2024  03/01/2025
# ..                                ...     ...         ...         ...
# 995                            Supply     0.0  04/27/2024  06/01/2023
# 996                            Demand     0.0  05/28/2024  08/18/2024
# 997                            Supply  1000.0  06/01/2023  12/01/2023
# 998                            Supply  1800.0  04/27/2024         NaN
# 999                           Unknown     0.0         NaN         NaN
#
#                                      location bedrooms bathrooms
# 0                                San Jose, CA        2         2
# 1               88 E San Carlos, San Jose, CA        2         3
# 2                                San Jose, CA        1         1
# 3                                San Jose, CA        1         1
# 4    Edge San Jose neighborhood, San Jose, CA        5         2
# ..                                        ...      ...       ...
# 995                              San Jose, CA        1         1
# 996                              San Jose, CA        1         1
# 997       5 minute walking distance from SJSU        2         2
# 998                              San Jose, CA        1         1
# 999                              San Jose, CA        1         1
#
# [1000 rows x 7 columns]

# %%
# Convert non-numerical fields into numerical only
# "Not found" was converted to 1 as a listing assumes there is at least 1 bedroom available
# For a range of bedrooms, the higher value was chosen
df["bedrooms"] = df["bedrooms"].str.replace("Not found","1")
df["bedrooms"] = df["bedrooms"].str.replace("Shared","0.5")
df["bedrooms"] = df["bedrooms"].str.replace("2-3","3")
df["bedrooms"] = df["bedrooms"].str.replace("double occupancy","2")
df["bedrooms"] = df["bedrooms"].str.replace("1 single, 1 shared","2")
df["bedrooms"] = df["bedrooms"].str.replace("2 or 3","3")
df["bedrooms"] = df["bedrooms"].str.replace("3-4","4")
df["bedrooms"] = df["bedrooms"].str.replace("4-5","5")
df.bedrooms = df.bedrooms.astype(float)

# %%
# "Not found" was converted to 1 as a listing assumes there is at least 1 bathroom available
# For a range of bathrooms, the higher value was chosen
df["bathrooms"] = df["bathrooms"].str.replace("Not found","1")
df["bathrooms"] = df["bathrooms"].str.replace("1 private, shared","1.5")
df["bathrooms"] = df["bathrooms"].str.replace("1 or 2","2")
df["bathrooms"] = df["bathrooms"].str.replace("1-3","3")
df.bathrooms = df.bathrooms.astype(float)

# %%
#did not implement due to Excessive Rate Limiter (bot abuse prevention)

#from geopy.geocoders import Nominatim
#
#geolocator = Nominatim(user_agent="myApp")
#
#df[['latitude', 'longitude']] = df['location'].apply(
#    geolocator.geocode).apply(lambda x: pd.Series(
#        [x.latitude, x.longitude], index=['location_lat', 'location_long']))

# %%
print(df)
# Out:
#     Supply(Selling)_or_Demand(Buying)    rent    fromDate      toDate  \
# 0                              Supply     0.0  04/01/2024  05/01/2024
# 1                              Supply  1280.0  06/01/2024  08/01/2024
# 2                              Demand  1250.0  07/27/2024  08/01/2024
# 3                              Supply  1220.0  04/27/2024         NaN
# 4                              Supply  1000.0  03/01/2024  03/01/2025
# ..                                ...     ...         ...         ...
# 995                            Supply     0.0  04/27/2024  06/01/2023
# 996                            Demand     0.0  05/28/2024  08/18/2024
# 997                            Supply  1000.0  06/01/2023  12/01/2023
# 998                            Supply  1800.0  04/27/2024         NaN
# 999                           Unknown     0.0         NaN         NaN
#
#                                      location  bedrooms  bathrooms
# 0                                San Jose, CA       2.0        2.0
# 1               88 E San Carlos, San Jose, CA       2.0        3.0
# 2                                San Jose, CA       1.0        1.0
# 3                                San Jose, CA       1.0        1.0
# 4    Edge San Jose neighborhood, San Jose, CA       5.0        2.0
# ..                                        ...       ...        ...
# 995                              San Jose, CA       1.0        1.0
# 996                              San Jose, CA       1.0        1.0
# 997       5 minute walking distance from SJSU       2.0        2.0
# 998                              San Jose, CA       1.0        1.0
# 999                              San Jose, CA       1.0        1.0
#
# [1000 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Supply(Selling)_or_Demand(Buying)  1000 non-null   object
#  1   rent                               1000 non-null   float64
#  2   fromDate                           851 non-null    object
#  3   toDate                             454 non-null    object
#  4   location                           1000 non-null   object
#  5   bedrooms                           1000 non-null   float64
#  6   bathrooms                          1000 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 54.8+ KB

# %%
#drop buyer listings
df = df.drop(df[df['Supply(Selling)_or_Demand(Buying)']== 0].index)

#drop unknown listings
df = df.drop(df[df['Supply(Selling)_or_Demand(Buying)']== 2].index)

#only the supply listings remain
#drop column for supply/demand/unknown labels since we know that every entry is part of supply
df = df.drop(df.columns[0], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rent       1000 non-null   float64
#  1   fromDate   851 non-null    object
#  2   toDate     454 non-null    object
#  3   location   1000 non-null   object
#  4   bedrooms   1000 non-null   float64
#  5   bathrooms  1000 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 47.0+ KB

# %%
df_train = df[["rent", "fromDate", "toDate", "location", "bedrooms", "bathrooms"]]

# %%
# Encode category type columns into numerical type
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df_categories = ['location', 'toDate', 'fromDate']

for column in df_categories:
    df_train[column] = label_encoder.fit_transform(df_train[column])

# %%
# Normalize the numerical features
numerical_features = ['rent', 'bedrooms', 'toDate', 'fromDate', 'bathrooms']

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_train[numerical_features] = scaler.fit_transform(df_train[numerical_features])

# %%
# Use the Nearest Neighbors model
nn_model = NearestNeighbors(metric='euclidean')
nn_model.fit(df_train)

# Disable warning about not having feature names
nn_model.feature_names_in_ = None

# %%
def recommend_similar_listings(index, num_recommendations=5):
    distances, indexes = nn_model.kneighbors(df_train.iloc[index].values.reshape(1, -1), n_neighbors=num_recommendations+1) #including the initial interest for NN calc
    recommended_indexes = indexes.squeeze()[1:] #only want to keep the indexes, exclude the initial interest
    interested_listing  =  df_train.iloc[[index]]
    recommended_listings = df_train.iloc[recommended_indexes]
    mse = np.mean(distances ** 2)
    #rmse = np.sqrt(mse)
    
    #sum the mse values for averaging later
    global mseSum
    mseSum += mse

    return print("--------------------------------------------------------------------\nYour Interested Listing Index #", x, "\n", interested_listing, "\n\nHere are", num_recommendations, "similar listings as recommendation:\n", recommended_listings, "\n\nMean Squared Error between interested and recommended listings: ", mse, "\n")

# %%
def myFunction(x):
    index = x # Index x in the dataframe
    recommend_similar_listings(index)

# %%
# Get the number of rows in the DataFrame
num_rows = len(df_train)
mseSum = 0

# Loop this function for every row in the dataframe to find five recommendations for each index
# Calculates mean squared error after every iteration

for x in range(num_rows):
    myFunction(x)
# Out:
# --------------------------------------------------------------------
# Your Interested Listing Index # 0
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 0 -0.197975 -1.131042 -1.968106       171  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 20  -0.197628 -1.176041 -2.111773       171  0.536416   0.955185
# 942 -0.197241 -0.996043 -1.704715       171  0.536416   0.955185
# 146 -0.197375 -1.423539 -2.423054       171  0.536416   0.955185
# 135 -0.197218 -1.378539 -1.465268       171  0.536416   0.955185
# 708 -0.197388 -0.501048 -1.297656       171  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  0.260549197078215
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 1
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 1 -0.197349 -0.636046 -1.034265        69  0.536416    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 45  -0.197349 -0.636046 -1.082154        69  0.536416    2.41126
# 190 -0.197669  1.208936 -2.542777        70  1.668095    2.41126
# 29  -0.197145 -0.253550 -1.082154        69 -0.595263   -0.50089
# 469 -0.197156  0.173946 -1.034265        69 -0.595263   -0.50089
# 951 -0.197380 -0.636046 -1.082154        68 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  6.508912190351858
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 2
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 2 -0.197363  0.038947 -1.034265       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 786 -0.197241  0.038947 -1.034265       171 -0.595263   -0.50089
# 710 -0.197437  0.128946 -1.034265       171 -0.595263   -0.50089
# 584 -0.197975  0.128946 -1.034265       171 -0.595263   -0.50089
# 408 -0.197975  0.038947 -0.914542       171 -0.595263   -0.50089
# 372 -0.197148  0.173946 -1.034265       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.008126466157830704
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 3
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 3 -0.197378 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 742 -0.197378 -1.086042  0.785528       171 -0.595263   -0.50089
# 634 -0.197378 -1.086042  0.785528       171 -0.595263   -0.50089
# 127 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 569 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 41  -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  4.79690695093709e-11
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 4
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 4 -0.197486 -1.176041 -2.183607       107  3.931454   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 87  -0.197510 -1.198541 -2.399109       108  3.931454   0.955185
# 748 -0.197486 -0.321049 -2.446998       108  3.931454   0.955185
# 536 -0.197398  0.196446 -1.010320       105  3.931454   2.411260
# 924 -0.197574 -1.108542 -1.896272       106  0.536416   2.411260
# 6   -0.197543 -1.153541  0.785528       105  1.668095   0.955185
#
# Mean Squared Error between interested and recommended listings:  7.483404862026876
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 5
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 5 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 6
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 6 -0.197543 -1.153541  0.785528       105  1.668095   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 574 -0.197510 -1.086042  0.785528       105  0.536416  -0.500890
# 337 -0.197584  0.668941  0.785528       105  1.668095   0.227148
# 265 -0.197645 -1.086042  0.785528       105 -0.595263  -0.500890
# 312 -0.197339 -1.086042  0.091133       104 -0.595263  -0.500890
# 656 -0.197975  0.196446  0.785528       105 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  5.383248306822267
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 7
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 7 -0.197975  -0.29855 -1.201877       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 596 -0.197975 -0.253550 -1.201877       171 -0.595263   -0.50089
# 419 -0.197204 -0.163551 -1.273711       171 -0.595263   -0.50089
# 977 -0.197206 -0.298550 -1.034265       171 -0.595263   -0.50089
# 680 -0.197975 -0.253550 -1.034265       171 -0.595263   -0.50089
# 727 -0.197975 -0.253550 -1.034265       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.018957108760956704
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 8
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 8 -0.197388  1.343935  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 164 -0.197388  1.343935  0.785528       171 -0.595263   -0.50089
# 792 -0.197363  1.343935  0.785528       171 -0.595263   -0.50089
# 136 -0.197437  1.343935  0.785528       171 -0.595263   -0.50089
# 42  -0.197469  1.343935  0.785528       171 -0.595263   -0.50089
# 393 -0.197290  1.343935  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  3.2134879406538724e-09
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 9
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 9 -0.197427 -0.636046 -1.465268       105 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 538 -0.197143  0.173946 -1.082154       105 -0.595263   -0.50089
# 797 -0.197449 -0.636046 -1.082154       104 -0.595263   -0.50089
# 312 -0.197339 -1.086042  0.091133       104 -0.595263   -0.50089
# 23  -0.197427 -0.636046 -1.034265       103 -0.595263   -0.50089
# 265 -0.197645 -1.086042  0.785528       105 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.504810866664297
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 10
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 10 -0.197198 -0.636046 -1.082154       211  1.668095    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 531 -0.197120  0.511443 -1.082154       211  1.668095   2.411260
# 505 -0.197120  0.511443 -1.082154       211  1.668095   0.955185
# 527 -0.197192 -1.423539 -1.465268       211  0.536416   0.955185
# 501 -0.197156  0.196446 -1.441324       210  2.799775   3.867334
# 974 -0.197427 -0.636046  0.210856       213  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  3.8695021493300406
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 11
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 11 -0.197975 -0.861044 -0.603261       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 915 -0.197975 -0.928544 -0.699040       171 -0.595263   -0.50089
# 996 -0.197975 -0.726046 -0.651151       171 -0.595263   -0.50089
# 927 -0.197975 -0.861044 -0.435649       171 -0.595263   -0.50089
# 948 -0.197211 -0.771045 -0.866652       171 -0.595263   -0.50089
# 946 -0.197975 -0.973543 -0.866652       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.03697462753631791
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 12
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 12 -0.197975 -0.411049 -0.148313       183 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 376 -0.197045  0.938938  0.210856       183 -0.595263   -0.50089
# 62  -0.197412 -1.198541 -1.537102       183 -0.595263   -0.50089
# 377 -0.197045  0.938938  0.785528       183 -0.595263   -0.50089
# 361 -0.196506 -1.086042 -0.339870       182  0.536416   -0.50089
# 213 -0.197363  1.118937  0.785528       183 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.1967996554568567
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 13
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 13 -0.197975 -0.636046 -0.387759       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 909 -0.197329 -0.501048 -0.387759       171 -0.595263   -0.50089
# 927 -0.197975 -0.861044 -0.435649       171 -0.595263   -0.50089
# 738 -0.197314 -0.388549 -0.387759       171 -0.595263   -0.50089
# 996 -0.197975 -0.726046 -0.651151       171 -0.595263   -0.50089
# 11  -0.197975 -0.861044 -0.603261       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.051156281851935936
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 14
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 14 -0.197645 -1.131042  0.785528       102  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 312 -0.197339 -1.086042  0.091133       104 -0.595263  -0.500890
# 23  -0.197427 -0.636046 -1.034265       103 -0.595263  -0.500890
# 653 -0.196727  0.173946  0.785528       104 -0.595263  -0.500890
# 448 -0.197975  0.038947 -0.435649       100  0.536416   0.955185
# 574 -0.197510 -1.086042  0.785528       105  0.536416  -0.500890
#
# Mean Squared Error between interested and recommended listings:  6.09471440445509
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 15
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 15 -0.19762 -1.176041  0.785528        16  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 702 -0.197682 -0.276050  0.785528        15 -0.595263  -0.500890
# 759 -0.197265 -1.086042  0.785528        17  0.536416   0.955185
# 115 -0.197388 -1.086042  0.785528        14  0.536416  -0.500890
# 689 -0.197667 -0.658546 -0.172258        18  0.536416   0.955185
# 717 -0.197657 -1.086042  0.785528        13 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  4.636856954586718
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 16
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 16 -0.196163 -1.131042  0.785528       192  1.668095   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 819 -0.197486 -0.636046  0.785528       193  0.536416   -0.50089
# 21  -0.197412 -1.086042  0.785528       190 -0.595263   -0.50089
# 831 -0.197241 -0.636046 -1.034265       191 -0.595263   -0.50089
# 968 -0.197314  0.196446  0.785528       194 -0.595263   -0.50089
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  7.971851427271235
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 17
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 17 -0.197388 -1.086042  0.785528       188  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 51  -0.197339 -1.086042  0.785528       188  0.536416   -0.50089
# 985 -0.197388 -1.086042  0.785528       188 -0.595263   -0.50089
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
# 540 -0.196849  0.196446  0.785528       189 -0.595263   -0.50089
# 21  -0.197412 -1.086042  0.785528       190 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.376473419645508
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 18
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 18 -0.197192 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 18  -0.197192 -1.086042  0.785528       171 -0.595263   -0.50089
# 639 -0.197178 -1.086042  0.785528       171 -0.595263   -0.50089
# 603 -0.197178 -1.086042  0.785528       171 -0.595263   -0.50089
# 636 -0.197178 -1.086042  0.785528       171 -0.595263   -0.50089
# 628 -0.197167 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.0079053012100297e-10
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 19
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 19 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 20
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 20 -0.197628 -1.176041 -2.111773       171  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 0   -0.197975 -1.131042 -1.968106       171  0.536416   0.955185
# 146 -0.197375 -1.423539 -2.423054       171  0.536416   0.955185
# 942 -0.197241 -0.996043 -1.704715       171  0.536416   0.955185
# 135 -0.197218 -1.378539 -1.465268       171  0.536416   0.955185
# 708 -0.197388 -0.501048 -1.297656       171  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  0.3260485225039076
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 21
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 21 -0.197412 -1.086042  0.785528       190 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
# 540 -0.196849  0.196446  0.785528       189 -0.595263   -0.50089
# 985 -0.197388 -1.086042  0.785528       188 -0.595263   -0.50089
# 831 -0.197241 -0.636046 -1.034265       191 -0.595263   -0.50089
# 358 -0.197975  0.668941 -0.076479       189 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  3.078868389122849
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 22
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 23
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 23 -0.197427 -0.636046 -1.034265       103 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 797 -0.197449 -0.636046 -1.082154       104 -0.595263   -0.50089
# 312 -0.197339 -1.086042  0.091133       104 -0.595263   -0.50089
# 9   -0.197427 -0.636046 -1.465268       105 -0.595263   -0.50089
# 538 -0.197143  0.173946 -1.082154       105 -0.595263   -0.50089
# 653 -0.196727  0.173946  0.785528       104 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.880531299768944
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 24
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 24 -0.196898  1.343935  0.785528       131 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 519 -0.197192  1.343935  0.785528       130 -0.595263  -0.500890
# 249 -0.197241  1.073937  0.785528       132  0.536416  -0.500890
# 291 -0.197412  0.826440  0.067189       129 -0.595263  -0.500890
# 935 -0.197975  0.646441  0.713694       132  0.536416   0.955185
# 724 -0.197227  0.646441 -0.052535       132  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  3.1032694434744124
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 25
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 25 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 276 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 200 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 55  -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 82  -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 247 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 26
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 26 -0.197241 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 967 -0.197241 -1.086042  0.785528       171 -0.595263   -0.50089
# 26  -0.197241 -1.086042  0.785528       171 -0.595263   -0.50089
# 410 -0.197192 -1.086042  0.785528       171 -0.595263   -0.50089
# 18  -0.197192 -1.086042  0.785528       171 -0.595263   -0.50089
# 636 -0.197178 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  1.464695563242442e-09
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 27
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 28
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 29
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 29 -0.197145  -0.25355 -1.082154        69 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 469 -0.197156  0.173946 -1.034265        69 -0.595263   -0.50089
# 951 -0.197380 -0.636046 -1.082154        68 -0.595263   -0.50089
# 251 -0.197149 -1.423539 -1.082154        67 -0.595263   -0.50089
# 152 -0.197149 -1.086042  0.091133        67 -0.595263   -0.50089
# 45  -0.197349 -0.636046 -1.082154        69  0.536416    2.41126
#
# Mean Squared Error between interested and recommended listings:  3.7795807340081655
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 30
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 30 -0.197412 -1.086042  0.785528       198 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 638 -0.197241 -0.388549  0.785528       199 -0.595263  -0.500890
# 185 -0.197265 -1.086042  0.785528       199  0.536416   0.955185
# 349 -0.197544  0.668941 -0.315926       199 -0.595263  -0.500890
# 88  -0.197104 -1.311040 -1.369490       197 -0.595263  -0.500890
# 862 -0.197461 -0.636046 -1.082154       196 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  4.094328308585251
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 31
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 31 -0.197437 -1.086042  0.785528       184  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 12  -0.197975 -0.411049 -0.148313       183 -0.595263   -0.50089
# 361 -0.196506 -1.086042 -0.339870       182  0.536416   -0.50089
# 377 -0.197045  0.938938  0.785528       183 -0.595263   -0.50089
# 376 -0.197045  0.938938  0.210856       183 -0.595263   -0.50089
# 213 -0.197363  1.118937  0.785528       183 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  4.851710242235037
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 32
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 32 -0.197349 -0.636046 -1.082154       171  0.536416    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 125 -0.197354 -1.423539 -1.082154       171  0.536416    2.41126
# 109 -0.197354 -1.423539 -1.082154       171  0.536416    2.41126
# 446 -0.197510 -1.086042 -1.800493       171  0.536416    2.41126
# 196 -0.197388 -1.086042 -2.087829       171  0.536416    2.41126
# 886 -0.197376  0.488943 -1.082154       171  0.536416    2.41126
#
# Mean Squared Error between interested and recommended listings:  0.7397124222633193
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 33
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 33 -0.197584 -0.636046  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 952 -0.197975 -0.636046  0.785528       171 -0.595263   -0.50089
# 758 -0.197178 -0.636046  0.785528       171 -0.595263   -0.50089
# 934 -0.197608 -0.748545  0.785528       171 -0.595263   -0.50089
# 988 -0.197633 -0.748545  0.785528       171 -0.595263   -0.50089
# 721 -0.197650 -0.253550  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.028602629084687775
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 34
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 34 -0.197412 -1.176041 -1.968106       171  2.799775   3.867334
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 648 -0.197486 -1.086042 -1.034265       171  2.799775    2.41126
# 90  -0.197147 -1.086042 -1.082154       171  1.668095    2.41126
# 823 -0.197399 -0.636046 -1.082154       171  1.668095    2.41126
# 589 -0.197241  0.173946 -1.465268       171  1.668095    2.41126
# 502 -0.197229  0.173946 -1.465268       171  1.668095    2.41126
#
# Mean Squared Error between interested and recommended listings:  3.77064240944969
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 35
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 35 -0.197461 -1.176041 -2.111773       219 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 79  -0.197339 -1.176041 -2.111773       220  1.668095   0.955185
# 219 -0.197143 -1.086042  0.785528       221 -0.595263  -0.500890
# 945 -0.197339  0.196446  0.785528       217 -0.595263  -0.500890
# 139 -0.197645 -1.086042  0.785528       222 -0.595263  -0.500890
# 595 -0.197339  1.343935  0.785528       220 -0.595263   0.955185
#
# Mean Squared Error between interested and recommended listings:  11.698452751067064
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 36
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 36 -0.197192  0.871439 -2.135718        88  2.799775    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 99  -0.197290 -1.198541 -2.399109        87  1.668095   3.139297
# 932 -0.197535 -0.951043 -1.393434        86  2.799775  -0.500890
# 718 -0.196996 -0.253550  0.785528        90  0.536416   1.683222
# 50  -0.197278 -1.086042 -2.063884        85  0.536416   0.955185
# 972 -0.197388 -0.636046 -1.728659        89 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  14.41583790180629
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 37
#          rent  fromDate   toDate  location  bedrooms  bathrooms
# 37 -0.197378 -1.086042 -2.03994       171  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 775 -0.197378 -1.086042 -2.087829       171  0.536416   -0.50089
# 883 -0.197407 -1.041042 -1.465268       171  0.536416   -0.50089
# 834 -0.197645 -0.636046 -1.465268       171  0.536416   -0.50089
# 933 -0.196947 -0.838544 -1.225822       171  0.536416   -0.50089
# 374 -0.197210 -1.086042 -2.087829       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.47905724179004405
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 38
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 38 -0.197339 -1.041042 -1.752604       188 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
# 985 -0.197388 -1.086042  0.785528       188 -0.595263   -0.50089
# 358 -0.197975  0.668941 -0.076479       189 -0.595263   -0.50089
# 51  -0.197339 -1.086042  0.785528       188  0.536416   -0.50089
# 17  -0.197388 -1.086042  0.785528       188  0.536416   -0.50089
#
# Mean Squared Error between interested and recommended listings:  5.227273846506946
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 39
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 39 -0.197559 -1.041042 -1.465268       171  3.931454   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 583 -0.197498  0.196446 -1.010320       171  3.931454   0.955185
# 947 -0.197521 -0.636046 -1.465268       171  3.931454  -0.500890
# 975 -0.197975 -0.253550 -1.034265       171  3.931454  -0.500890
# 444 -0.197461  0.196446 -1.010320       171  2.799775   1.683222
# 648 -0.197486 -1.086042 -1.034265       171  2.799775   2.411260
#
# Mean Squared Error between interested and recommended listings:  2.347720590175006
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 40
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 40 -0.197238 -1.086042  0.785528       171  1.668095   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 555 -0.196261 -0.006052  0.785528       171  1.668095   0.955185
# 220 -0.197313 -1.086042  0.785528       171  0.536416   0.955185
# 665 -0.197388 -1.086042  0.785528       171  0.536416   0.955185
# 84  -0.197735 -1.288540  0.785528       171  0.536416   0.955185
# 189 -0.196960 -1.423539  0.785528       171  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  1.0740136244000398
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 41
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 41 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 897 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 743 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 569 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 41  -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
# 156 -0.197388 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 42
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 42 -0.197469  1.343935  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 395 -0.197486  1.343935  0.785528       171 -0.595263   -0.50089
# 136 -0.197437  1.343935  0.785528       171 -0.595263   -0.50089
# 164 -0.197388  1.343935  0.785528       171 -0.595263   -0.50089
# 8   -0.197388  1.343935  0.785528       171 -0.595263   -0.50089
# 292 -0.197559  1.343935  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  3.7913553313422495e-09
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 43
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 43 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 44
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 44 -0.197368 -1.086042  0.785528        28  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 225 -0.197975 -1.086042  0.785528        29 -0.595263  -0.500890
# 714 -0.197498  0.083947 -0.124368        26  0.536416   0.955185
# 95  -0.197290 -1.086042 -1.465268        27 -0.595263  -0.500890
# 92  -0.197451  1.343935 -1.465268        27  0.536416   0.955185
# 381 -0.197375  0.646441 -1.752604        30  1.668095   0.955185
#
# Mean Squared Error between interested and recommended listings:  7.793291662296423
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 45
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 45 -0.197349 -0.636046 -1.082154        69  0.536416    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 1   -0.197349 -0.636046 -1.034265        69  0.536416    2.41126
# 190 -0.197669  1.208936 -2.542777        70  1.668095    2.41126
# 29  -0.197145 -0.253550 -1.082154        69 -0.595263   -0.50089
# 469 -0.197156  0.173946 -1.034265        69 -0.595263   -0.50089
# 951 -0.197380 -0.636046 -1.082154        68 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  6.484831670100888
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 46
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 46 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 47
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 47 -0.197398 -1.176041  0.354524        23  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 956 -0.197975 -0.883544 -0.746929        24 -0.595263  -0.500890
# 796 -0.197711 -0.816045 -0.699040        22  0.536416   0.955185
# 515 -0.197574  0.173946 -1.082154        21 -0.595263  -0.500890
# 693 -0.197473 -0.253550  0.785528        25  2.799775  -0.500890
# 155 -0.197486 -1.086042  0.785528        20 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  6.290086406295781
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 48
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 48 -0.197143 -1.086042  0.785528        38  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 820 -0.197417 -0.253550 -1.034265        39 -0.595263   0.955185
# 764 -0.197417 -0.276050 -1.058209        40 -0.595263   0.955185
# 662 -0.197417 -0.276050 -1.058209        40 -0.595263   0.955185
# 803 -0.197637 -0.793545 -0.722984        36 -0.595263  -0.500890
# 159 -0.197975  1.343935  0.785528        37 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  7.504224301780208
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 49
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 49 -0.196359  1.343935  0.570026       171  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 221 -0.197388  1.343935  0.785528       171  0.536416   0.955185
# 581 -0.197975  1.388934  0.785528       171  0.536416   0.955185
# 465 -0.197740  0.533942  0.785528       171  0.536416   0.955185
# 75  -0.197488  1.343935  0.785528       171 -0.595263   0.955185
# 306 -0.197975  1.388934  0.785528       171  1.668095   0.955185
#
# Mean Squared Error between interested and recommended listings:  0.5756247433149488
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 50
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 50 -0.197278 -1.086042 -2.063884        85  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 918 -0.197975 -0.928544 -0.699040        84  0.536416  -0.500890
# 551 -0.197887 -0.051052 -0.770874        83  0.536416   0.955185
# 932 -0.197535 -0.951043 -1.393434        86  2.799775  -0.500890
# 99  -0.197290 -1.198541 -2.399109        87  1.668095   3.139297
# 387 -0.197721  0.668941  0.162967        82  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  7.946070558419497
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 51
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 51 -0.197339 -1.086042  0.785528       188  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 17  -0.197388 -1.086042  0.785528       188  0.536416   -0.50089
# 985 -0.197388 -1.086042  0.785528       188 -0.595263   -0.50089
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
# 540 -0.196849  0.196446  0.785528       189 -0.595263   -0.50089
# 21  -0.197412 -1.086042  0.785528       190 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.3764734096519518
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 52
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 52 -0.197322 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 405 -0.197339 -1.086042  0.785528       171 -0.595263   -0.50089
# 205 -0.197339 -1.086042  0.785528       171 -0.595263   -0.50089
# 859 -0.197363 -1.086042  0.785528       171 -0.595263   -0.50089
# 634 -0.197378 -1.086042  0.785528       171 -0.595263   -0.50089
# 3   -0.197378 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  1.4440688633535927e-09
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 53
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 53 -0.197045 -1.086042  0.234801        99  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 448 -0.197975  0.038947 -0.435649       100  0.536416   0.955185
# 210 -0.197486 -1.086042  0.785528        97 -0.595263  -0.500890
# 124 -0.197192 -1.333540 -2.303331        98  0.536416  -0.500890
# 134 -0.197241 -1.333540 -2.303331        99  0.536416   0.955185
# 14  -0.197645 -1.131042  0.785528       102  0.536416  -0.500890
#
# Mean Squared Error between interested and recommended listings:  5.975245013325346
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 54
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 54 -0.197378  1.343935  0.785528       171  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 285 -0.197388  1.343935  0.785528       171  0.536416   -0.50089
# 110 -0.197388  1.343935  0.785528       171  0.536416   -0.50089
# 270 -0.197682  1.343935  0.785528       171  0.536416   -0.50089
# 289 -0.197682  1.343935  0.785528       171  0.536416   -0.50089
# 567 -0.196947  1.343935  0.785528       171  0.536416   -0.50089
#
# Mean Squared Error between interested and recommended listings:  6.17202027686447e-08
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 55
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 55 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 276 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 200 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 55  -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 82  -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
# 247 -0.197975 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 56
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 56  0.047188 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 965  0.047213 -1.086042  0.785528       171 -0.595263   -0.50089
# 591  0.096211 -1.086042  0.785528       171 -0.595263   -0.50089
# 683  0.096236 -1.086042  0.785528       171 -0.595263   -0.50089
# 939  0.145283 -1.086042  0.785528       171 -0.595263   -0.50089
# 78   0.169721 -1.131042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.00524513565677262
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 57
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 57 -0.197363 -1.198541 -1.632881       135  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 981 -0.197975 -1.018543 -1.944161       135  1.668095   0.955185
# 852 -0.197975 -0.636046 -0.411704       135 -0.595263  -0.500890
# 791 -0.197535  0.106446 -1.130043       134 -0.595263  -0.500890
# 774 -0.197975 -0.523547 -1.656825       137  1.668095  -0.500890
# 495 -0.197339  0.196446 -0.339870       136 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  4.80849405440566
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 58
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 58 -0.197129  1.343935  0.785528       165 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 645 -0.197975  1.343935  0.785528       163 -0.595263   -0.50089
# 121 -0.197574 -1.086042  0.785528       165 -0.595263   -0.50089
# 766 -0.197378 -1.086042  0.689749       165 -0.595263   -0.50089
# 122 -0.197574 -1.086042  0.785528       164 -0.595263   -0.50089
# 794 -0.197241 -0.478548 -0.459593       167 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  5.265883858773705
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 59
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 59 -0.197129 -1.198541 -2.207552       206 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 802 -0.197144 -0.636046 -1.082154       205 -0.595263  -0.500890
# 112 -0.196960 -1.423539 -2.423054       207  0.536416   0.955185
# 258 -0.197147 -1.243541 -1.082154       204 -0.595263  -0.500890
# 172 -0.197133 -1.423539 -1.082154       203 -0.595263  -0.500890
# 129 -0.197133 -1.423539 -1.082154       203 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  5.497278781435139
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 60
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 60 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 61
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 61 -0.197731 -1.086042  0.785528        76 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 547 -0.197339  0.196446  0.785528        77 -0.595263  -0.500890
# 252 -0.197657 -1.086042  0.785528        75  0.536416   0.955185
# 928 -0.197975 -0.591047 -0.531427        78 -0.595263  -0.500890
# 655 -0.197564 -0.276050 -1.465268        74 -0.595263   0.955185
# 145 -0.197388 -1.086042  0.665805        80  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  7.380421089900935
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 62
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 62 -0.197412 -1.198541 -1.537102       183 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 12  -0.197975 -0.411049 -0.148313       183 -0.595263   -0.50089
# 361 -0.196506 -1.086042 -0.339870       182  0.536416   -0.50089
# 303 -0.197262  0.916439 -2.111773       183  0.536416   -0.50089
# 376 -0.197045  0.938938  0.210856       183 -0.595263   -0.50089
# 31  -0.197437 -1.086042  0.785528       184  0.536416   -0.50089
#
# Mean Squared Error between interested and recommended listings:  4.611970938419435
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 63
#         rent  fromDate    toDate  location  bedrooms  bathrooms
# 63  8.61857 -1.198541  0.785528       171 -0.595263   -0.50089
#
# ...
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 979
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 979 -0.197535 -1.086042  0.785528       171  2.799775    2.41126
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 815 -0.197437 -1.086042  0.785528       171  2.799775   3.139297
# 606 -0.197430 -0.253550  0.785528       171  2.799775   1.683222
# 869 -0.197219 -0.748545  0.785528       171  2.799775   3.867334
# 438 -0.197131  0.196446  0.785528       171  1.668095   2.411260
# 648 -0.197486 -1.086042 -1.034265       171  2.799775   2.411260
#
# Mean Squared Error between interested and recommended listings:  1.7040491813823728
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 980
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 980 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 981
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 981 -0.197975 -1.018543 -1.944161       135  1.668095   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 57  -0.197363 -1.198541 -1.632881       135  0.536416   0.955185
# 774 -0.197975 -0.523547 -1.656825       137  1.668095  -0.500890
# 378 -0.197241  0.556442 -0.579317       135  2.799775   2.411260
# 413 -0.197241  0.398944  0.785528       135  1.668095   0.955185
# 852 -0.197975 -0.636046 -0.411704       135 -0.595263  -0.500890
#
# Mean Squared Error between interested and recommended listings:  5.800016994430547
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 982
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 982 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 983
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 983 -0.197975 -1.063542 -1.106099       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 119 -0.197241 -1.086042 -1.082154       171 -0.595263   -0.50089
# 912 -0.197975 -1.041042 -1.034265       171 -0.595263   -0.50089
# 704 -0.197314 -1.086042 -1.034265       171 -0.595263   -0.50089
# 991 -0.197290 -1.041042 -1.034265       171 -0.595263   -0.50089
# 68  -0.197354 -1.198541 -1.082154       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.006146411477059949
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 984
#           rent  fromDate   toDate  location  bedrooms  bathrooms
# 984 -0.197782 -0.636046  0.33058        46  0.536416   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 997 -0.197486 -0.658546  0.330580        46  0.536416   0.955185
# 313 -0.197423  0.938938  0.210856        45  0.536416  -0.500890
# 140 -0.197741 -1.086042  0.785528        47  0.536416   0.955185
# 141 -0.197741 -1.086042  0.785528        47  0.536416   0.955185
# 118 -0.197273 -1.086042  0.785528        47  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  2.700742115522391
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 985
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 985 -0.197388 -1.086042  0.785528       188 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 17  -0.197388 -1.086042  0.785528       188  0.536416   -0.50089
# 51  -0.197339 -1.086042  0.785528       188  0.536416   -0.50089
# 94  -0.197192 -1.086042 -0.435649       189 -0.595263   -0.50089
# 540 -0.196849  0.196446  0.785528       189 -0.595263   -0.50089
# 21  -0.197412 -1.086042  0.785528       190 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  1.9495739732487098
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 986
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 986 -0.197388 -0.748545  0.617915       171 -1.161103   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 934 -0.197608 -0.748545  0.785528       171 -0.595263   -0.50089
# 988 -0.197633 -0.748545  0.785528       171 -0.595263   -0.50089
# 33  -0.197584 -0.636046  0.785528       171 -0.595263   -0.50089
# 758 -0.197178 -0.636046  0.785528       171 -0.595263   -0.50089
# 952 -0.197975 -0.636046  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.2965518635872258
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 987
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 987 -0.197701 -0.636046  0.210856       213  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 974 -0.197427 -0.636046  0.210856       213  0.536416   0.955185
# 322 -0.197096 -1.086042 -1.800493       214  0.536416   0.955185
# 876 -0.197206 -0.636046 -1.082154       212 -0.595263  -0.500890
# 737 -0.197345 -1.086042 -0.746929       211  0.536416  -0.500890
# 527 -0.197192 -1.423539 -1.465268       211  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  4.33171555109332
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 988
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 988 -0.197633 -0.748545  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 934 -0.197608 -0.748545  0.785528       171 -0.595263   -0.50089
# 33  -0.197584 -0.636046  0.785528       171 -0.595263   -0.50089
# 952 -0.197975 -0.636046  0.785528       171 -0.595263   -0.50089
# 758 -0.197178 -0.636046  0.785528       171 -0.595263   -0.50089
# 963 -0.197657 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.02531206778465241
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 989
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 989 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 990
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 990  3.965305 -0.928544 -1.656825       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 938  3.475663 -0.748545 -0.914542       171 -0.595263   -0.50089
# 700  3.720484 -0.411049 -0.339870       171 -0.595263   -0.50089
# 851  5.679640 -0.681046 -0.387759       171 -0.595263   -0.50089
# 599  3.720582 -1.086042  0.785528       171 -0.595263   -0.50089
# 541  4.210273 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  3.265943254896591
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 991
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 991 -0.19729 -1.041042 -1.034265       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 912 -0.197975 -1.041042 -1.034265       171 -0.595263   -0.50089
# 704 -0.197314 -1.086042 -1.034265       171 -0.595263   -0.50089
# 119 -0.197241 -1.086042 -1.082154       171 -0.595263   -0.50089
# 983 -0.197975 -1.063542 -1.106099       171 -0.595263   -0.50089
# 116 -0.197354 -1.198541 -1.034265       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.006136062821381401
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 992
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 992 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 993
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 993  0.047286 -1.086042  0.785528       171 -1.726943  -1.956964
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 986 -0.197388 -0.748545  0.617915       171 -1.161103   -0.50089
# 965  0.047213 -1.086042  0.785528       171 -0.595263   -0.50089
# 56   0.047188 -1.086042  0.785528       171 -0.595263   -0.50089
# 591  0.096211 -1.086042  0.785528       171 -0.595263   -0.50089
# 683  0.096236 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  2.7083979591566556
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 994
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 994 -0.197314 -1.063542 -1.776549        66  1.668095   1.683222
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 664 -0.197642 -0.321049 -0.483538        65  0.536416   1.683222
# 861 -0.197253 -0.636046 -1.034265        67  2.799775   3.867334
# 45  -0.197349 -0.636046 -1.082154        69  0.536416   2.411260
# 251 -0.197149 -1.423539 -1.082154        67 -0.595263  -0.500890
# 1   -0.197349 -0.636046 -1.034265        69  0.536416   2.411260
#
# Mean Squared Error between interested and recommended listings:  7.802286492354342
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 995
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 995 -0.197975 -1.086042 -1.776549       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 616 -0.197510 -1.086042 -1.752604       171 -0.595263   -0.50089
# 950 -0.197559 -1.041042 -1.752604       171 -0.595263   -0.50089
# 966 -0.197559 -1.041042 -1.752604       171 -0.595263   -0.50089
# 113 -0.197488 -1.041042 -1.752604       171 -0.595263   -0.50089
# 920 -0.197975 -1.086042 -1.920216       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.00483491874064633
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 996
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 996 -0.197975 -0.726046 -0.651151       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 11  -0.197975 -0.861044 -0.603261       171 -0.595263   -0.50089
# 915 -0.197975 -0.928544 -0.699040       171 -0.595263   -0.50089
# 948 -0.197211 -0.771045 -0.866652       171 -0.595263   -0.50089
# 761 -0.197975 -0.501048 -0.699040       171 -0.595263   -0.50089
# 746 -0.197975 -0.501048 -0.699040       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.03635304044064939
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 997
#           rent  fromDate   toDate  location  bedrooms  bathrooms
# 997 -0.197486 -0.658546  0.33058        46  0.536416   0.955185
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 118 -0.197273 -1.086042  0.785528        47  0.536416   0.955185
# 141 -0.197741 -1.086042  0.785528        47  0.536416   0.955185
# 140 -0.197741 -1.086042  0.785528        47  0.536416   0.955185
# 984 -0.197782 -0.636046  0.330580        46  0.536416  -0.500890
# 154 -0.197741 -1.086042  0.785528        48  0.536416   0.955185
#
# Mean Squared Error between interested and recommended listings:  1.779930342852312
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 998
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 998 -0.197094 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 350 -0.197143 -1.086042  0.785528       171 -0.595263   -0.50089
# 620 -0.197163 -1.086042  0.785528       171 -0.595263   -0.50089
# 373 -0.197020 -1.086042  0.785528       171 -0.595263   -0.50089
# 628 -0.197167 -1.086042  0.785528       171 -0.595263   -0.50089
# 639 -0.197178 -1.086042  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  4.1621962128745335e-09
#
# --------------------------------------------------------------------
# Your Interested Listing Index # 999
#           rent  fromDate    toDate  location  bedrooms  bathrooms
# 999 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Here are 5 similar listings as recommendation:
#          rent  fromDate    toDate  location  bedrooms  bathrooms
# 83 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 28 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 27 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 5  -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
# 22 -0.197975  1.388934  0.785528       171 -0.595263   -0.50089
#
# Mean Squared Error between interested and recommended listings:  0.0

# %%
#divides the sum of all mse values and divides by the number of rows to give the average mse from all runs
avg_mse = mseSum / num_rows
print("Average Mean Squared Error: ", avg_mse)
# Out:
# Average Mean Squared Error:  2.616198851668428
